# %%
import pandas as pd
import numpy as np


from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB

from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import f1_score

# %%
DATA_JSON_FILE = '2.1 SpamData/01_Processing/email-text-data.json'

# %%
data = pd.read_json(DATA_JSON_FILE)

# %%
data.tail()
# Out:
#                                                 MESSAGE  CATEGORY  \
# 5790  I'm one of the 30,000 but it's not working ver...         0
# 5791  Damien Morton quoted:\n\n>W3C approves HTML 4 ...         0
# 5792  On Mon, 2002-07-22 at 06:50, che wrote:\n\n\n\...         0
# 5793  Once upon a time, Manfred wrote :\n\n\n\n> I w...         0
# 5794  If you run Pick, and then use the "New FTOC" b...         0
#
#                                    FILE_NAME
# 5790  00609.dd49926ce94a1ea328cce9b62825bc97
# 5791  00957.e0b56b117f3ec5f85e432a9d2a47801f
# 5792  01127.841233b48eceb74a825417d8d918abf8
# 5793  01178.5c977dff972cd6eef64d4173b90307f0
# 5794  00747.352d424267d36975a7b40b85ffd0885e

# %%
data.shape
# Out:
# (5795, 3)

# %%
data.sort_index(inplace=True)

# %%
data.tail()
# Out:
#                                                 MESSAGE  CATEGORY  \
# 5790  I'm one of the 30,000 but it's not working ver...         0
# 5791  Damien Morton quoted:\n\n>W3C approves HTML 4 ...         0
# 5792  On Mon, 2002-07-22 at 06:50, che wrote:\n\n\n\...         0
# 5793  Once upon a time, Manfred wrote :\n\n\n\n> I w...         0
# 5794  If you run Pick, and then use the "New FTOC" b...         0
#
#                                    FILE_NAME
# 5790  00609.dd49926ce94a1ea328cce9b62825bc97
# 5791  00957.e0b56b117f3ec5f85e432a9d2a47801f
# 5792  01127.841233b48eceb74a825417d8d918abf8
# 5793  01178.5c977dff972cd6eef64d4173b90307f0
# 5794  00747.352d424267d36975a7b40b85ffd0885e

# %%
vectorizer = CountVectorizer(stop_words='english')

# %%
all_features = vectorizer.fit_transform(data.MESSAGE)

# %%
all_features.shape
# Out:
# (5795, 102512)

# %%
vectorizer.vocabulary_
# Out:
# {'dear': 32664,
#  'homeowner': 47966,
#  'rates': 76257,
#  'lowest': 59288,
#  'point': 72205,
#  '40': 7778,
#  'years': 98324,
#  'help': 47132,
#  'best': 23080,
#  'rate': 76254,
#  'situation': 82203,
#  'matching': 60849,
#  'needs': 64666,
#  'hundreds': 48538,
#  'lenders': 57945,
#  'home': 47938,
#  'improvement': 51329,
#  'refinance': 76979,
#  'second': 80863,
#  'mortgage': 62943,
#  'equity': 38930,
#  'loans': 58982,
#  'perfect': 70389,
#  'credit': 30920,
#  'service': 81253,
#  '100': 1455,
#  'free': 42708,
#  'owners': 68628,
#  'new': 64903,
#  'buyers': 25564,
#  'obligation': 66726,
#  'just': 54974,
#  'quick': 75454,
#  'simple': 82057,
#  'form': 42361,
#  'jump': 54925,
#  'start': 84010,
#  'future': 43265,
#  'plans': 71847,
#  'today': 87910,
#  'visit': 92787,
#  'http': 48428,
#  '61': 10046,
#  '145': 2232,
#  '116': 1831,
#  '186': 2705,
#  'user0201': 91206,
#  'index': 51568,
#  'asp': 20381,
#  'afft': 17558,
#  'qm10': 75015,
#  'unsubscribe': 90823,
#  'light': 58396,
#  'watch': 94147,
#  'attention': 20691,
#  'computer': 29700,
#  'users': 91234,
#  'special': 83376,
#  'package': 69032,
#  'deal': 32648,
#  'norton': 65746,
#  'systemworks': 85615,
#  '2002': 3465,
#  'software': 82971,
#  'suite': 84883,
#  'professional': 73272,
#  'edition': 37496,
#  'includes': 51458,
#  'yes': 98372,
#  'feature': 40997,
#  'packed': 69040,
#  'utilities': 91340,
#  'low': 59278,
#  'price': 73044,
#  'protect': 73519,
#  'unwanted': 90879,
#  'hazardous': 46795,
#  'viruses': 92753,
#  'secure': 80907,
#  'private': 73136,
#  'valuable': 91923,
#  'information': 51802,
#  'allow': 18674,
#  'transfer': 88426,
#  'files': 41477,
#  'send': 81073,
#  'mails': 60324,
#  'safely': 79976,
#  'backup': 22142,
#  'data': 32264,
#  'easily': 37216,
#  'improve': 51326,
#  'pc': 69668,
#  'performance': 70397,
#  'superior': 84997,
#  'integral': 52201,
#  'diagnostics': 33839,
#  'great': 45499,
#  '300': 5548,
#  'combined': 29369,
#  'retail': 77862,
#  'value': 91926,
#  '29': 4747,
#  '99': 13922,
#  'shipping': 81668,
#  'don': 34934,
#  'fall': 40553,
#  'prey': 73038,
#  'destructive': 33376,
#  'hackers': 46378,
#  'delay': 32992,
#  'copy': 30400,
#  'euro': 39362,
#  'specialdiscounts4u': 83378,
#  'com': 29350,
#  'email': 38156,
#  'screened': 80641,
#  'filtered': 41512,
#  'house': 48194,
#  'opt': 67808,
#  'compliance': 29625,
#  'state': 84046,
#  'laws': 57594,
#  'wish': 95555,
#  'mailing': 60301,
#  'lists': 58657,
#  'thousands': 87291,
#  'providers': 73571,
#  'dvd': 36500,
#  'optoutd': 67866,
#  'html': 48403,
#  'multi': 63546,
#  'message': 61597,
#  'mime': 62057,
#  'format': 42371,
#  '_nextpart_000_1cdc19_01c25366': 15017,
#  '4b57f3a0': 8400,
#  'content': 30194,
#  'type': 89241,
#  'text': 86862,
#  'plain': 71820,
#  'charset': 27742,
#  'windows': 95468,
#  '1252': 1983,
#  'encoding': 38412,
#  'quoted': 75522,
#  'printable': 73100,
#  'dare': 32220,
#  'try': 88784,
#  'better': 23128,
#  'annuity': 19324,
#  '20': 3443,
#  'guaranteed': 45806,
#  '0a': 909,
#  'year': 98317,
#  'surrender': 85125,
#  'charge': 27722,
#  'agent': 17719,
#  'commission': 29454,
#  'age': 17701,
#  '80': 11972,
#  '09': 840,
#  '800': 11973,
#  '888': 12786,
#  '7641': 11337,
#  'ext': 39961,
#  '103': 1587,
#  'mail': 60233,
#  'phone': 71219,
#  'city': 28328,
#  'pmg': 72075,
#  'financial': 41535,
#  'services': 81255,
#  'deposits': 33212,
#  '000': 1,
#  '25': 4389,
#  'totalling': 88140,
#  '999': 13973,
#  'want': 94025,
#  'receive': 76690,
#  'mailings': 60305,
#  'does': 34833,
#  'communication': 29495,
#  'sent': 81117,
#  'insurance': 52176,
#  'professionals': 73277,
#  'removed': 77387,
#  'list': 58604,
#  'reply': 77524,
#  'instead': 52131,
#  'www': 96395,
#  'insuranceiq': 52177,
#  'optout': 67863,
#  'legal': 57888,
#  'notice': 65801,
#  'insiq': 52063,
#  'htm': 48400,
#  'iso': 53020,
#  '8859': 12780,
#  'head': 46943,
#  'title': 87596,
#  'meta': 61618,
#  'equiv': 38931,
#  '3d': 6339,
#  '3diso': 7004,
#  'body': 24340,
#  'bgcolor': 23248,
#  '666666': 10342,
#  '000000': 4,
#  'font': 42193,
#  'face': 40438,
#  'arial': 20068,
#  'helvetica': 47152,
#  'sans': 80153,
#  'serif': 81198,
#  'table': 85992,
#  'width': 95353,
#  '550': 9191,
#  'border': 24531,
#  'align': 18586,
#  'center': 27351,
#  'cellpadding': 27321,
#  'cellspacing': 27329,
#  'bordercolor': 24534,
#  'ffffff': 41261,
#  'tr': 88312,
#  'td': 86420,
#  'img': 51142,
#  'src': 83747,
#  'iiq': 50827,
#  'images': 51097,
#  '20020822': 3530,
#  '101': 1508,
#  'gif': 44578,
#  'alt': 18755,
#  'height': 47089,
#  '55': 9190,
#  'br': 24763,
#  '102': 1532,
#  'jpg': 54708,
#  '47': 8201,
#  '248': 4346,
#  '201': 3627,
#  '32': 5709,
#  '142': 2212,
#  '202': 3643,
#  '10': 1454,
#  '508': 8943,
#  'size': 82232,
#  '535': 9097,
#  '115': 1815,
#  '95': 13739,
#  'method': 61654,
#  'post': 72498,
#  'action': 16850,
#  '65': 10240,
#  '217': 3918,
#  '159': 2393,
#  'response': 77776,
#  'background': 22105,
#  'colspan': 29335,
#  '15': 2296,
#  'right': 78326,
#  'input': 51998,
#  'contactname': 30159,
#  '50': 8880,
#  'rowspan': 78956,
#  'valign': 91912,
#  'middle': 61939,
#  'q3': 74435,
#  '43': 8001,
#  '30': 5547,
#  'nbsp': 64477,
#  'submit': 84685,
#  'btnsubmit': 25240,
#  'hidden': 47438,
#  'hdnrecipienttxt': 46912,
#  'rhock': 78217,
#  'pmgsecurities': 72078,
#  'hdnsubjecttxt': 46913,
#  'ad': 16925,
#  'inquiry': 52011,
#  'sentto': 81129,
#  '304704': 5577,
#  '416': 7919,
#  'cccccc': 27087,
#  'href': 48321,
#  'important': 51286,
#  'domain': 34898,
#  'names': 64284,
#  'finally': 41528,
#  'available': 20998,
#  'general': 44173,
#  'public': 73920,
#  'discount': 34213,
#  'prices': 73051,
#  'register': 77080,
#  'exciting': 39654,
#  'biz': 23704,
#  'info': 51763,
#  'original': 68025,
#  'net': 64784,
#  '14': 2181,
#  'brand': 24822,
#  'extensions': 39977,
#  'recently': 76707,
#  'approved': 19789,
#  'icann': 49631,
#  'rights': 78337,
#  'biggest': 23512,
#  'benefit': 22989,
#  'course': 30628,
#  'currently': 31378,
#  'easier': 37213,
#  'attractive': 20714,
#  'easy': 37230,
#  'remember': 77331,
#  'affordable': 17553,
#  'domains': 34907,
#  'registration': 77090,
#  'fees': 41048,
#  'include': 51456,
#  'access': 16607,
#  'use': 91183,
#  'control': 30280,
#  'panel': 69221,
#  'manage': 60512,
#  'sincerely': 82093,
#  'administrator': 17157,
#  'remove': 77372,
#  'address': 17047,
#  'promotional': 73400,
#  'company': 29524,
#  'click': 28665,
#  'centralremovalservice': 27366,
#  'cgi': 27559,
#  'bin': 23577,
#  'g1': 43497,
#  'ss2': 83790,
#  '5592oxer3': 9228,
#  '424uqkh2259kcdl5': 7971,
#  '189geil31': 2732,
#  'line': 58492,
#  'away': 21194,
#  'cd': 27152,
#  'people': 70352,
#  'like': 58425,
#  'month': 62825,
#  'let': 58007,
#  'talk': 86128,
#  'product': 73245,
#  'samples': 80092,
#  'earn': 37188,
#  '45': 8104,
#  'days': 32367,
#  'think': 87198,
#  'kidding': 56005,
#  'earned': 37190,
#  'precisely': 72799,
#  '26': 4494,
#  '087': 804,
#  '58': 9326,
#  '94': 13701,
#  'doing': 34869,
#  'scanned': 80399,
#  'checks': 27823,
#  'online': 67578,
#  'eyes': 40077,
#  've': 92148,
#  'tweaked': 89111,
#  'things': 87195,
#  'little': 58689,
#  'busy': 25526,
#  'aren': 20034,
#  'good': 45170,
#  'talking': 86134,
#  'work': 95897,
#  'time': 87496,
#  'helped': 47134,
#  'julie': 54913,
#  '750': 11270,
#  'week': 94953,
#  'jeff': 54017,
#  '6500': 10242,
#  'weeks': 94962,
#  'exact': 39581,
#  'business': 25500,
#  'plan': 71828,
#  'tell': 86645,
#  'exactly': 39582,
#  'expect': 39824,
#  'starting': 84014,
#  'guesswork': 45840,
#  'seriously': 81201,
#  'evaluate': 39402,
#  'happy': 46586,
#  'fly': 42003,
#  'los': 59214,
#  'angeles': 19195,
#  'expense': 39847,
#  'closer': 28771,
#  'look': 59144,
#  'following': 42169,
#  'postal': 72502,
#  'number': 66159,
#  'area': 20023,
#  'code': 29147,
#  'mailto': 60332,
#  'cashflows99': 26846,
#  'excite': 39650,
#  'subject': 84662,
#  'free_cd': 42715,
#  'senate': 81069,
#  '1618': 2434,
#  'section': 80893,
#  '301': 5561,
#  'states': 84059,
#  'statement': 84057,
#  'transmissions': 88473,
#  'unsolicited': 90807,
#  'commercial': 29443,
#  'electronic': 38011,
#  'recipient': 76734,
#  'person': 70515,
#  'initiates': 51905,
#  'transmission': 88472,
#  'stopped': 84328,
#  'cost': 30523,
#  'sending': 81087,
#  'originating': 68033,
#  'word': 95881,
#  '_nextpart_000_00b8_51e06b6a': 14954,
#  'c8586b31': 26268,
#  'base64': 22438,
#  'sgvyzsdzihrozsbob3r0zxn0ihroaw5nigluierwrhmuie5vdyb5b3ugy2fu': 81458,
#  'ig1ha2ugysbwzxjzb25hbcbiywnrdxancmnvchkgb2ygysbevkqgcmlnahqg': 50278,
#  'b250bybdrc1sliagt3vyicjib3qiig5ldybzb2z0d2fyzsblyxnpbhkgdgfr': 21636,
#  'zxmgew91ihrocm91z2gncnrozsbzdgvwcyb0bybtywtligegy29wesbvzib5': 101108,
#  'b3vyig93bibevkrzlg0kdqpot1cgsu5dtfveruqgrk9siezsruuhienvchkg': 21874,
#  'uexbwvnuqvrjt04sie1vu0ldl01qm3mgyw5kigfsbcbtb2z0d2fyzs4ncg0k': 89776,
#  'lsbtdgvwigj5ifn0zxagsw50zxjhy3rpdmugsw5zdhj1y3rpb25zia0klsbb': 59447,
#  'bgwgu29mdhdhcmugvg9vbhmgsw5jbhvkzwqgt24gq0qgdqotie5vierwrcbc': 23338,
#  'dxjuzxigumvxdwlyzwqgdqotiezsruugtgl2zsbuzwnobmljywwgu3vwcg9y': 36649,
#  'dcanci0gmzagrgf5ifjpc2sgrnjlzsbucmlhbcbbdmfpbgfibgugdqotiezs': 32463,
#  'ruugrhzkie1vdmllig9mihlvdxigy2hvawnlichmsu1jveveifrjtuugt0zg': 79410,
#  'rvihkq0kdqpxzsboyxzliefsbcb0agugc29mdhdhcmugew91ig5lzwqgdg8g': 79447,
#  'q09qwsb5b3vyig93bibevkqgtw92awvzlg0kdqpodhrwoi8vc2ftlm1vdghv': 74345,
#  'c3quy29tl3bvcy9kdmquahrtdqorkysrkysrkysrkysrkysrkysrkysrkysr': 26125,
#  'kysrkysrkysrkysrkysrkysrkysrkysrkysrkysrkysrkysrkysrkysrkysr': 56982,
#  'kysrkysrdqpuaglzigvtywlsighhcybizwvuihnjcmvlbmvkigfuzcbmawx0': 56974,
#  'zxjlzcbiesbvdxigaw4gag91c2ugiijpufqtt1vuiiigc3lzdgvtigluia0k': 101091,
#  'y29tcgxpyw5jzsb3axroihn0yxrligxhd3muielmihlvdsb3axnoihrvicjp': 97861,
#  'ufqtt1vuiibmcm9tihroaxmgbwfpbgluzybhcyb3zwxsia0kyxmgdghligxp': 89816,
#  'c3rzig9mihrob3vzyw5kcyagb2ygb3rozxigzw1hawwgchjvdmlkzxjzihbs': 26134,
#  'zwfzzsb2axnpdcagdqoncmh0dha6ly9zyw0ubw90ag9zdc5jb20vcg9zl29w': 100946,
#  'dg91dgquahrtba0kkysrkysrkysrkysrkysrkysrkysrkysrkysrkysrkysr': 33562,
#  'kysrkysrkysrkysrkysrkysrkysrkysrkysrkysrkysrkysrkysrkysrkw0k': 56981,
#  'odqyovplwm01ltu4ngjsyw4yodi2enhhrdetmtm4qm1uvdywothuswnvny0y': 66968,
#  'mjbyawtnmzyymgw1mg': 62329,
#  'multipart': 63568,
#  'reader': 76525,
#  'understand': 90439,
#  'legible': 57903,
#  'xx9adb9a99': 97661,
#  '1a5b9adbxx': 2916,
#  '7bit': 11547,
#  'k1': 55200,
#  'erotikverlag': 39034,
#  'sucht': 84813,
#  'pornodarsteller': 72407,
#  'wenn': 95034,
#  'du': 36325,
#  'spaß': 83355,
#  'sex': 81336,
#  'hast': 46711,
#  'und': 90385,
#  'nebenbei': 64629,
#  'geld': 44153,
#  'verdienen': 92286,
#  'willst': 95427,
#  'bewirb': 23148,
#  'auch': 20759,
#  'dich': 33878,
#  'wir': 95533,
#  'suchen': 84811,
#  'natürliche': 64403,
#  'frauen': 42664,
#  'männer': 64010,
#  'jeden': 54007,
#  'alters': 18775,
#  'mollig': 62726,
#  'kein': 55713,
#  'problem': 73183,
#  'infos': 51821,
#  'unter': 90851,
#  '0930': 863,
#  '830': 12212,
#  '13': 2065,
#  '22': 3953,
#  'aus': 20838,
#  'österreich': 102335,
#  '01': 307,
#  '90': 13531,
#  '87': 12694,
#  '54': 9139,
#  'deutschland': 33438,
#  '86': 12603,
#  'eu': 39312,
#  'min': 62076,
#  'callcenter': 26473,
#  'hier': 47445,
#  'ein': 37850,
#  'bild': 23542,
#  'einer': 37855,
#  'produktion': 73259,
#  'das': 32254,
#  'vorstellungsvideo': 93105,
#  'siehst': 81927,
#  'web': 94830,
#  'darsteller': 32249,
#  'php': 71273,
#  'solltest': 83022,
#  'unserem': 90793,
#  'newsletter': 64980,
#  'interesse': 52278,
#  'mehr': 61411,
#  'haben': 46358,
#  'dann': 32207,
#  'trage': 88381,
#  'bitte': 23684,
#  'newsletr': 64979,
#  'image': 51080,
#  'jpeg': 54705,
#  'disposition': 34366,
#  'attachment': 20660,
#  'filename': 41474,
#  'lenkawolfgangk1': 57957,
#  '9j': 14220,
#  '4aaqskzjrgabageasabiaad': 8354,
#  '4rr': 8754,
#  'rxhpzgaasukqaagaaaajaa8bagafaaaaegaaabab': 79539,
#  'agamaaaagaaaabibawabaaaaaqaaabobbqabaaaajaaaabsbbqabaaaalaaaacgbawabaaaa': 17685,
#  'agaaadibagauaaaanaaaabmcawabaaaaagaaagmhbaabaaaasaaaapgbaabtt05zaabeq1it': 17679,
#  'uemxmtbfiabiaaaaaqaaaegaaaabaaaamjawmjowndoxnyaxodoymdo1oaarajqcbqabaaaa': 89765,
#  'ggeaaj2cbqabaaaaigeaackiawabaaaaagaaaacqbwaeaaaamdixmaoqagauaaaakgeaaasq': 44438,
#  'agauaaaapgeaaagrbwaeaaaaaqidaakrbqabaaaaugeaaasscgabaaaawgeaaawsbqabaaaa': 17690,
#  'ygeaaamsawabaaaaaqaaaaqsbqabaaaa0geaaacgbwaeaaaamdewmaggawabaaaaaqaaaaog': 98428,
#  'baabaaaagaqaaakgbaabaaaayamaaawgbaabaaaa2geaaaaaaaabaaaamgaaalqaaabkaaaa': 22060,
#  'mjawmjowndoxnyaxodoymdo1oaaymdayoja0oje3ide4ojiwoju4aaiaaaabaaaaaaaaagqa': 62326,
#  'aacqaaaazaaaacoaaaakaaaaagabaaiabaaaafi5oaacaacabaaaadaxmdaaaaaacgcgkgma': 16084,
#  'aqaaaayaaaapaqiabqaaahycaaaqaqiadaaaahwcaaasaqmaaqaaaaeaaacgkguaaqaaaigc': 19860,
#  'aacgkguaaqaaajacaacgkgmaaqaaaaiaaaayaqiafaaaajgcaacgkgqaaqaaak0caacgkgqa': 16079,
#  'aqaaaesyaaaaaaaau09owqaarenslvbdmtewrsaasaaaaaeaaabiaaaaaqaaadiwmdi6mdq6': 19862,
#  'mtcgmtg6mja6ntgaap': 63410,
#  '8qbogaaaqubaqebaqeaaaaaaaaaaaecawqfbgcicqolaqadaqeb': 13364,
#  'aqebaqebaaaaaaaaaqidbaugbwgjcgsqaaibawmcbamfbqqeaaabfqecawaeequsitfbbhnr': 19885,
#  'yqcicrqygzghccncscevuthwjdnicoijchyxgbkajsynkckqndu2nzg5okneruzhselku1rv': 98903,
#  'vldywvpjzgvmz2hpann0dxz3ehl6g4sfhoeiiyqsk5svlpeymzqio6slpqeoqaqys7s1tre4': 92926,
#  'ubrcw8tfxsfiycrs09tv1tfy2drh4upk5ebn6onq8flz9px29': 89609,
#  'j5': 53567,
#  'heaagecbaqdbacfbaqa': 46942,
#  'aqj3aaecaxeebsexbhjbuqdhcrmimoeifekrobhbcsmzuvavynlrchyknoel8rcygromjygp': 19898,
#  'kju2nzg5okneruzhselku1rvvldywvpjzgvmz2hpann0dxz3ehl6gooehyahiimkkpoulzax': 56178,
#  'mjmaoqokpaanqkmqsro0tba3ulm6wspexcbhymnk0tpu1dbx2nna4upk5ebn6onq8vp09fb3': 62349,
#  'pn6': 72111,
#  '9sahaagbaqfbamgbqqfbgygbwkpcqkicaksdq0kdxutfhyvexuugbsihrgzibkufr4o': 14428,
#  'hiajjcynjhccki0qjs0ijsylaqygbgkhcrejcrelgbuyjsuljsuljsuljsuljsuljsuljsul': 47420,
#  'jsuljsuljsuljsuljsuljsuljsuljsuljsuljsx': 54813,
#  'waarcab4akadaseaahebaxeb': 93818,
#  '9oadamb': 14323,
#  'aairaxeapwdxxttxvjahwmda6ohvovs4jyz9zxmvyxpbo1gtcg31e3l1mapu': 16153,
#  'ymmsb8v': 98690,
#  'en5': 38377,
#  '1u6pmsnwys4ow7pbi4': 3312,
#  'pwu4umbg0jpyz1ee8zkdz5yk7dspbncb2xxpjagyeuhzuwg3aoums': 74195,
#  'i6jlajrae': 48949,
#  'fczoxbgclzyzclpno6e1q6paryqpd2cu2rovyf5': 40902,
#  'otquuwskjkrftg4my': 68257,
#  'cnim': 29011,
#  'tu9rutj1liodrtjnkfklxgc4zqstx0iyfrzgdyqz719': 88906,
#  'hqqru1nh5xjslldvnbrreqom54qr': 48296,
#  'ywc': 99163,
#  'yrosct3f8skh2ppqey4h5u7d6jdcp8kgkhgektrsnfs5tlh45qhcqdcgvm0ao8gvordu': 98947,
#  'myw0kup45u': 63940,
#  'maeme4': 60165,
#  'lv9m0dw9qjkk0maxuct7dukvtnge5apb86': 59692,
#  'xw9kvsxifdyuvglh2vq': 97621,
#  'nu9b8q2dq8s2koillr2mycedp4vf9am0zvpqhjuims6vgwtussofxzuyndolvugdxka': 66118,
#  'z0pq': 99453,
#  'dkz8hbgeeiur0q': 34609,
#  'cljpi4zxnswh6idmbdvmjtng': 28739,
#  '9wehdseat64rkmrhft1k95pysrkfr06y': 14524,
#  'rnnr0h4kcw7mljoov': 78652,
#  'klcttnjxtpjvidb3fvjb6tbloly1caupwchowpfb6fu10phv402e0e': 56243,
#  'cxiob7wccgejs8tdhuj7w57agvrmuxkpxs6hxgc4f1z8y': 31585,
#  'i7gp4gehzfhk3wku87o4nyh8hv': 48965,
#  'u18zajcsbfvuritjzvap9wafeuszscuw5888rxci5cuhsiqbcjbhr60ez6d3xxucdtwo0seq': 89351,
#  'ffrsbieldeveehwkjbhiqplcsc4rnmit0pmhliw2mas3k2nycy9wfrzivzpadsbtw1anif8y': 41284,
#  '7zo': 11964,
#  '3opm6f8aju38q8bcx9': 7580,
#  'mppce37fo1rhulguo5e3ip3yp0rnblwtanieosumurr5jllg8': 63146,
#  'kjkjr0pbvtzt3kfotzpjhz1vtez1omubyrfxuay7ipy7hkvzubih3vavmou61prqitlq6ds7': 56162,
#  'vda7ww': 92111,
#  'ot2wkdigz1rnqbnbh3dalivs5aqpewxnw7s': 68186,
#  'rgvitztstjzfxloswoajdqmo3ldti': 78161,
#  'hp0': 48234,
#  'lxhe9pnbneqedr': 59782,
#  've1gz3jznz2z0': 92150,
#  'etrp': 39295,
#  'fl82fic3dmrhi2w': 41778,
#  '8aaup54': 12883,
#  'kvupsmyiuy': 56857,
#  'juln': 54920,
#  'wdxwmidmmicdhmi0zc8eahndetato29nplhz': 94775,
#  'caqcb7c5x9a7inpxx0eaqqdfer': 26683,
#  '8dnghdhetrqg8c4zsmw9dxzc8nltqvnpuc1vli5ytumqlvofmuwzsd4w568': 13092,
#  '0r3ycflsvyyh': 1270,
#  'tshcqbxgv5mewjpex89bcuhkju09cj': 88810,
#  'x3p8ajwynvgh8yywrylvesd': 96634,
#  'oannffdsrjgo4la9': 66650,
#  'gbf1ojxbgwpfmtlhgbjpqivmyah11tyl2nb7w02b9yliv': 43976,
#  'ma6nry0kyyc81z1xdtnxh42snp': 60071,
#  'uxpiptoaztyvbfbsukz9otydtv2rwer3xnztrkc15b4y0ott5fvlrcrjeigcc8z': 91530,
#  'xfenhz8j': 97004,
#  'pixtp2ktmjvikg': 71614,
#  '07tfjujzrnbjpb04r22k2kntlesmfo54lmj2keft0': 764,
#  'vfpnoa68stjky9t': 92412,
#  'xrssln0': 97450,
#  'xrp7ti8yllglcakqrjpftxoo4qevppivyyh': 97447,
#  'u2fn8srarr9a3k9p1pcf9od8k9dn': 89390,
#  'zifyhkhb': 100176,
#  'y1wmxipzv2j5ttlzl': 97840,
#  'wlw1h7stzkm4ypdedopsvegoljobnagoa8vb': 95709,
#  'c7nu49xk': 26258,
#  'mhs8ht7k7luqxworxuhbitjptxh6n4cfwii5bk6wg7tjaz': 61828,
#  '48889': 8283,
#  'v8am1ljpu6xq3yuknfz': 91804,
#  'w5shtxny3c23lw12p43iucj15of0runi0magfztukjmrdjjt7opp714ojlchwn0': 93694,
#  'ehuqay2n': 37795,
#  '21hnxiooowfdbo9qqbuazxnm9wghox00dradrkx74rintvpmznmybc0kttsurxmiv4hj2eh3': 3944,
#  'rf1i0kut8awirgrkbcp24pbhbbzgmuml5wrnhjod0jxvvhpbqmltdbd0dfcbaufcgetxp': 78059,
#  'ikexw1bvjkiv94eqezb57qacc9m46ele0oxqk7pnqlsdctjf2l2n': 50955,
#  'evxdzcjz7io9wjww': 39500,
#  '0o': 1200,
#  'gy4ycfup69yegxxkh0rw18v9k1q5sc6xytvxsmybw64afpnp1xnparuwu40w49zysypzxmvo': 46049,
#  '92julkuocmyoldixjivzufo630inoeocagl79kllbngxgmwwfx3zhozjffulb': 13656,
#  'zwpwf': 100984,
#  'tte': 88850,
#  'wsnjibgzujhxv': 96198,
#  '8arry8nfl1pcxqtnwcoqh14z87dr2inc6dk86': 12992,
#  'eoxublnrbwkkbfx1xx69': 38784,
#  'ugqcc4qp80kvlxtalzu4m6btdnhs4wetjxyxjyfxrrebkkhphrxym5ours': 89865,
#  '9hfu4pwnvt0wo': 14194,
#  'juzrnv7vpi': 54999,
#  'wbcf6j0oagvzoe8qeklwxthmuz1rvbjlngcvp7bx28vajg4vf7plhasik': 94250,
#  'dgk': 33656,
#  'e4bgpyh646vvsotpztsyva6t5u9wdxa': 36914,
#  'hbyijrrfvv94xxtoggpphimftuaa1j7by7q7vysm': 46831,
#  'c1lktk9twnt5fc8m8f8ah': 25969,
#  'ahwbi': 18041,
#  'hv2lmgxopx8h': 48597,
#  'tcyrg4ne7hmuri': 86419,
#  'cx0f3jyousqfbjpt': 31573,
#  'fxlsydomnkq': 43390,
#  'wvxt': 96343,
#  'tdbxo7nwb4': 86427,
#  'ftduh0m': 43056,
#  'newwkxhe0g': 65007,
#  'ae9ap93t7celexekdgdh1r1cj': 17372,
#  'ucowfq8lmqkjuuupgssfuj86gkzjoppmulnf5i8o': 89662,
#  'gvpkx98yjazlcjdqmcsppytd7ip3abj': 45953,
#  'o1': 66463,
#  '58f1rhofaj0sy26rbm6e7kullrszjxb': 9358,
#  'esj': 39138,
#  'hpye': 48271,
#  'pxt9emrp9mkkbexaahqv4gav': 74232,
#  'at5': 20561,
#  'ex9xkmg9ls5735jwwmigweb3fvpnsigyhyplpijryurs9utsiteel7sytwlxesuqkhxkcgn3': 39575,
#  'pncpr3xcs4y2j07nxiom3hfz': 72125,
#  'wak6awgln7hhwxcaa1z5lrfik': 93941,
#  '165ml7m2zpyxg': 2481,
#  'kp8ttvd': 56521,
#  'ic60k9wse': 49246,
#  'zfu3neeh9x6hhevw9jfq5tw3ijyqc5714z8twahp8ciklxueg84zxtryjonyn': 99984,
#  'u9jxh1kfljn0': 89520,
#  'hrc0dpv9otzxi4hsqehhlz19q828c': 48314,
#  'dmyng17oqot0cslziy3mgdquohgd': 34713,
#  'ix3rbd13tl5gwjwarrbw550lwc0leujv5yvgov2lsmzbz0of5vx1c': 53344,
#  'exc242lnccdhp07fhx': 39608,
#  'tppq6pmpkuhytaooz5zx0x4m1itwfblhd3opoaik5ypmzecfx612ysturhnzgk6d': 88258,
#  'pshgseu': 73665,
#  'agm56hmvtpe3oh8f6euneerrcq': 17787,
#  'zovnur3lcjpubgfhwlqf81vz': 100532,
#  'xcqzptttodvctj2': 96901,
#  'hkiv': 47673,
#  'ok1tpe8es054iyv9r2l2qwxge': 67313,
#  'wpuk': 96035,
#  '9bmdxfemd3svk6jcmfdu0oxstjn1fxjbwvs7szbqv': 14055,
#  'oc15jrnjdunvu': 66807,
#  'krkq2cmojzvok68hhnufm9jkx2kjrjzpuzj4s1u6tpbuepjqzbzjburl': 56631,
#  'tdhv752fpaysberaya': 86434,
#  'p6cvalra0spmo14zu7lwsn4zwjkbv1jbb6iku4py': 68923,
#  'wsmrgyd1c9f': 96196,
#  'feqyg': 41111,
#  'ks2a8kdi56z7fnk': 56666,
#  '8a6q9hsrt4pyi4ymv42tdiuduf7o9cz5ioosmhbhjypl2jpo8v': 12858,
#  'b9khlun7dkvbwyxyk7yktgppbo5gnqkgnjcrnbhrvaxubbps15njpfbwqxawsngbbyqmdkya': 22030,
#  '78': 11412,
#  'lxk4t2uepgrgmzkl2pnrxtq0wrellu': 59785,
#  'timhjlcekecoaog4htpwotk5ne9sg4wuwfiyia': 87527,
#  'nvlnbmk9v': 66252,
#  'fuppgkjor5cjj655z': 43235,
#  'tdue': 86448,
#  'ihm49r2r2icevwo3cbesk9u8rlqzegsnh5msu6f': 50596,
#  'drhtpkwkwuepla': 36132,
#  'jwk8jh39joe7lt': 55064,
#  '2juu21whicobnh0pl3p2p3mbn5smc44osx': 5283,
#  'hp': 48233,
#  'ovmz': 68581,
#  'nrep9nbnrq4zwvcf5exivd3szrbvnyudoz1a9a6bqnh0': 65941,
#  'wsnxtkvumeyfvt9t': 96200,
#  'svosqrqqrt': 85241,
#  '1plc8ovacua': 3236,
#  'j69vikhj3ysrtyrkc': 53594,
#  'apxqvlk3hsraxrlhefwfar1mkz55nphnfidwtbid': 19841,
#  '5rg4jucyj8twfy5': 9807,
#  't9k5cwcrxi26rmrmchcc5rza8fg7r7ofnkolfntpg3whb6daryxdkzmb': 85890,
#  'nydgn': 66356,
#  'tdnbewkjevuxaxx6y6v83vl7sxmfz4ehsykjpxxuuntsjxcr90sst36k5pf8k5pxpb': 86441,
#  '6lrukgzs2abdihkhusy5aphi3y7jp71ejjsuzoqxbg0jydx': 10765,
#  'aahqelwcn08erk3yyyajtgme': 16139,
#  'zxwopdupfa3khaqsdng49': 101148,
#  'wr2iyilr81uwc09ilbqebfxqyeqgcktjoofsvotw7zwaboce': 96075,
#  'foynefbda8hpevvwdm7nizjgshy2nivwcdv50x2': 42504,
#  'h8a9bni3b3muhbyc88c1hejtfutrmn1p': 46296,
#  'k3sgdhb7sgomqfy': 55269,
#  'z1hfwhzxselqm6cljmydn8unfemy1qnrc': 99462,
#  'xd8k59v88': 96918,
#  'prtdo1jz': 73611,
#  'kayhhgayof1r5jfuhcvmfz4lfrqxttniwstjcamgqfx4czbg3fowhkbgkdghor3rlo1pujqu': 55543,
#  'wdteldeqczk5lywd5zxo': 94742,
#  '6hjtnlxant6dfyzu6ssgoxsnocdq': 10688,
#  'tweohil2fy': 89122,
#  'gzhlz4kv0rx': 46101,
#  '5mlqelqjhlnoszcnjldqo9fvdvpxdxfldxatbjasorricjmflvgeoj6jiqxmlozwds0rs9': 9702,
#  'c07xdd2sywvimwo80e27qq43gyycpzz06hvw95nnc2q3elphktnglso': 25936,
#  'hr5ert5hpsfeyapz': 48307,
#  'x13j4nwksz5d3kggmb17': 96552,
#  'wolrxjzqxsvq0ymwxgivjpvwxs3j6hv7anon2xzbuylhlssky4x': 95827,
#  'g8jka9porxjei9v0': 43638,
#  'wswl7y0parocx7diqpxd7gfwuwuc5lwl4uund1oxvlyjo7dw': 96219,
#  'tkndn': 87692,
#  '9avqtgmbsb3': 14034,
#  'z7gh7pmx8knpyn': 99618,
#  'f1r18nxvksr': 40212,
#  'h4wmwvt8pj7pf7josb7j8qiki5br6': 46227,
#  'nhxlv9ucdfemnksj2gaswarcq6xjnafqcd8qrjx3pbsu6o7jgerrgj9ca8': 65156,
#  'wihf2pvhg6k48': 95373,
#  '0uvna1xwpr0qivpysb8knlmrify4': 1342,
#  'wdrvz6rahpem': 94734,
#  'w5q8n9adkqlhva': 93692,
#  'wb0': 94221,
#  'wbd': 94257,
#  'fzvo066': 43469,
#  'n6dr4r7agzpxxrmsx8nvbkrcvup1z7g12ekfevq9q2p9ownjxtk': 64132,
#  'defimfkdvhvh0ufx8k': 32921,
#  'is3znu281rexboyre89qg1drlacgmebwohxhhz': 52938,
#  '9avpupu5c0xznqckakxgs0zkyadcocbij': 14033,
#  'brwxx': 25117,
#  '64qln4rkupue52yur5rqdgz': 10237,
#  'h9c16bzatopk7hkryld0580b': 46311,
#  'l9ctn4evlg7dmtjvk': 57252,
#  'rty': 79255,
#  'xaha7gdpft3ravdsuv1atzjpakycmrbiumocgjcpymgjn1roe1uep3zg6exyl221ayjg': 96805,
#  '8lrspubia3mneq': 13261,
#  'w2choeqo': 93638,
#  'bbptax81k8tle4kejs29o6llftkc7sqm': 22591,
#  'njj6dear1fuoulu': 65349,
#  'zsmqkbm52o31ubvi9ns9vj88na8noomtyentxr6fpx': 100711,
#  'coeiwt9bkw4nmqphcplgwx8yjpoev': 29176,
#  'ttxyqkdj1ejzamjck6oyeh3ygmxaimajgap6vuvtps': 88888,
#  'hkjkufn': 47675,
#  'tclbi7nqrxngwthefffpd': 86386,
#  'ydz1': 98310,
#  'vs3': 93275,
#  'lqdv9cdmrlt8vhpevqslv9rtur6nwmy4f2fdpky6hiectyywpvcmcdinwi7jmh3': 59352,
#  'lp0bivdkz6induwitidgmfja': 59299,
#  'ivfi8nlmuaawayvparjzaomohjie': 53253,
#  'hnjifjo9ub4tdga': 47815,
#  'uk': 90018,
#  'oxxgen': 68685,
#  'j3liayerniowjktxsy': 53554,
#  'mttgfhy': 63451,
#  'jtallazexurt0ov': 54827,
#  '75orxd': 11322,
#  'hfhutnmsgu2qzie': 47314,
#  's0xykdslt19emewrnrxhvxmtgdghjwppleqo3t7qg6gescqoh4': 79687,
#  'xnmrp2sb4zk8ctqbjhhub': 97316,
#  'rzrwdj04j': 79631,
#  'evzjyulcxy31m644fmingc8e8flwfexq3udsbnovjdwsh2sopx8a0v1svvozk9': 39504,
#  'a0ykyvf': 15334,
#  'zqjc0uamv84oc45y49etxp3mppedskyj6ch8v5v2wd0cnseynuxs0fu4ipe9ndmn': 100578,
#  'ljstd7rkyiiyftbip4v2': 58764,
#  'uf2x4h09yrw': 89783,
#  't47um77aquaq': 85796,
#  'phpjb6h869nbshyshjny': 71285,
#  'a0zyq': 15335,
#  'wq007lsq': 96039,
#  'gfebs3d2gql9nvidtkjb27j2nds': 44393,
#  'yrmqvjprzivkruncttpdwldvyksw5nxlms5': 98944,
#  '5znqcoxqjk9': 9982,
#  'ad5zrona2ydna9': 16956,
#  'ufrmtcpizuh7uxni8ftxstlc8sju': 89817,
#  'nruaudqqdwhc': 65956,
#  'vc7': 92058,
#  'q2dntz': 74413,
#  '9erkyun1nokyo6lggdhkdgsr71qw8mxq2whvwepesji7qcrm0rergibg3kdg7qffv': 14138,
#  '371dhjikhcgoec985rnkdkwsnbxvwqdr0i71edpqniqa': 6057,
#  'ijpipkvupdgvomvoi0z65zx': 50926,
#  '3qv7vzifvoenipzekmekdovvuuf9s4yto9ixbthfdol2rdpgy5ejlewjbhhxsopwqnqmrz28': 7629,
#  'qxkw7b23bhgacemasjrcpnjw6gbdssdldhgmcht7d9pwrlokz6tp': 75652,
#  '8uriopx': 13445,
#  'j9k3tsmaqcj': 53661,
#  'ug0ek1t9vlxsbk46dv8a6': 89833,
#  '8aorn9a2hyqevw65dzahcy': 12983,
#  'ftznsnluvy5fxnkka4iuohc': 43121,
#  'sqcaoedvpn09u1x7dxjew0ki5jljud2diurn9ottgdl2cm11nchxxbvxnvjp': 83664,
#  '0p8kox': 1226,
#  'ai4t': 18051,
#  'gpsyia6kj47l6de': 45327,
#  '4ultuu6vkecloewuwcdr3h0q9a6gdkqchvxs1c8umroylsv84kmdu57n': 8799,
#  '8a1rlwsu0ndmpofeszrr2u6lnqattqariu6imdvpbnjvmtic8': 12845,
#  'ybwukjgaxoooubxpkj305l': 98232,
#  '1ljdosohovyhp69dn': 3155,
#  'vsrldryvhckjooohtnzwsbqrahibwzlggywec': 93303,
#  'ptzeikdktjp': 73900,
#  'n8': 64158,
#  'qllmguecfnefcnkiqdetkwbppbwedzxx26mmiknnoxcqq2cevop88vdgt0jggv55gspeobkt': 74994,
#  '1ce0wansd5nvy9fx7j39qym0qcfsyqbsucsdkjjp': 2961,
#  'frqpwfkkzhkojtwajeyhdzz0': 42958,
#  'n1rcvi': 64058,
#  'usdeina': 91180,
#  'xbjb9uk1gznnhwxgau7qrrjpjcsr2bq3aw0cuseg7imbc9vyzrfm0otkvzbjtlw7': 96850,
#  '5zihwerxz': 9974,
#  'jveftdbjfdo2r3x1rdttozglst95eed': 55018,
#  'nbviqzge3etax1ztgnkeo49kco3rno': 64483,
#  'fk9twh1cmmazzowzpx8m': 41743,
#  'wcetbev7txcyewwoaxbhcf5xweondcdztt71ivxe': 94452,
#  'wbcxpqayx': 94256,
#  'mflwlbojrdracpu3ex5rcsoqmrmrefmbwnurzk9oxpot5fun26qen68kz5fqb7j3dmpehgcd': 61714,
#  'hrpefleivtyuc8azptsk0leqdyoadjawp6vkcbdqga5ht6': 48334,
#  'wpljls6joipkyemjah': 96021,
#  'aneq': 19181,
#  '02wn8x9wbosr16fjqmyrtd55kkhjjn': 485,
#  'peue1ercxytgadzvxmasddcmag4dhzszymht': 70604,
#  'nh61': 65126,
#  'pb0wjvstixnnk': 69628,
#  '5xw7rx3tqf': 9932,
#  '9ka': 14236,
#  '0sifbob3rvc2hvccazljaaoejjtqptcljlc29sdxrp': 1293,
#  'b24aaaaaeabiaaaaaqacaegaaaabaai4qklnba0yrlggr2xvymfsiexpz2h0aw5niefuz2xl': 21631,
#  'aaaaaaqaaaaeoejjtqqzekzyiedsb2jhbcbbbhrpdhvkzqaaaaaeaaaahjhcsu0d8wtqcmlu': 15895,
#  'dcbgbgfncwaaaakaaaaaaaaaaaeaoejjtqqkdknvchlyawdodcbgbgfnaaaaaaeaadhcsu0n': 32477,
#  'ebrkyxbhbmvzzsbqcmludcbgbgfncwaaaaakaaeaaaaaaaaaajhcsu0d9rddb2xvcibiywxm': 37326,
#  'dg9uzsbtzxr0aw5ncwaaaegal2zmaaeabgzmaayaaaaaaaeal2zmaaeaozmaaayaaaaaaaea': 33568,
#  'mgaaaaeawgaaaayaaaaaaaeanqaaaaealqaaaayaaaaaaae4qklna': 61745,
#  'gxq29sb3igvhjhbnnm': 46033,
#  'zxigu2v0dgluz3maaabwaad': 101076,
#  'gaaaaa': 43678,
#  'wpoaaaaap': 96023,
#  '8d6aaaaad': 13077,
#  'gaadhcsu0ecazhdwlkzxmaaaaaeaaaaaeaaajaaaacqaaaaaa4': 43687,
#  'qklnbb4nvvjmig92zxjyawrlcwaaaaqaaaaaoejjtqqablnsawnlcwaaaactaaaabgaaaaaa': 74948,
#  'aaaaaaabxgaaavqaaaazadaaoaawagoatablag4aawbhafcabwbsagyazwbhag4azwa0adca': 15882,
#  'nwatadiaoaaxadyaaaabaaaaaaaaaaaaaaaaaaaaaaaaaaeaaaaaaaaaaaaaavqaaahgaaaa': 66276,
#  'aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaadhcsu0eerfjq0mgvw50ywdnzwqgrmxh': 15777,
#  'zwaaaaebadhcsu0efbdmyxllcibjrcbhzw5lcmf0b3igqmfzzqaaaaqaaaaboejjtqqmfu5l': 100922,
#  'dybxaw5kb3dzifrodw1ibmfpbaaadseaaaabaaaavaaaahaaaad8aabuqaaadquagaab': 36695,
#  '7gaoqwrvymuaziaaaaab': 11670,
#  '9sahaamcagicqgmcqkmeqskcxev': 14430,
#  'dwwmdxuyexmvexmyeqwmdawmdbemdawmdawmdawmdawmdawmdawmdawmdawmdawmaq0lcw0o': 36609,
#  'draodhaudg4ofbqodg4ofbemdawmdberdawmdawmeqwmdawmdawmdawmdawmdawmdawmdawm': 36085,
#  'dawmdaz': 32344,
#  'waarcabwafqdasiaahebaxeb': 93822,
#  '90abaag': 13571,
#  '8qbpwaaaqubaqebaqeaaaaaaaaaawab': 13366,
#  'agqfbgcicqolaqabbqebaqebaqaaaaaaaaabaaidbaugbwgjcgsqaaeeaqmcbaifbwyibqmm': 17819,
#  'mweaahedbcesmqvbuwetingbmgyukagxqimkfvlbyjm0colrqwclklpw4ffjczuworkdjkst': 63773,
#  'vgrfwqn0nhfsvejl8roew9n14': 92483,
#  'ngj5skhbsvxntk9kw1xdxl9vzmdoawprbg1ub2n0dxz3eh': 65097,
#  'l6e3x9fn9xeaagibagqeawqfbgchbgu1aqaceqmhmrieqvfhcsitbtkbkrshsuijwvlr8dmk': 57197,
#  'yufygpjduxvjcztxjqyworkdbyy1wtjek1sjf2rfvtz0zelys4td03xj80aupiw0lctu5psl': 99050,
#  'tcxv5fvwznaglqa2xtbm9ic3r1dnd4exp7fh': 86417,
#  '9oadambaairaxeapwddpxxt4vovdaesuv2o': 14332,
#  'oz7vqkgodxatt0kz69fa26ldsboukgtc18qlmaqywoijaj8sglzsxbxncqnqccr9yc8iszuq': 68738,
#  'tmu9hhseppkbkh4vd7wf': 87827,
#  'trcvnowwpul91n81qz6b48j': 88542,
#  'hx': 48658,
#  '2kvvtbkkx5w31b': 5300,
#  'n1m': 64055,
#  'gw': 45962,
#  'hnx6t3u': 47832,
#  '0irczzumuslvirob0': 1082,
#  'rsb': 79123,
#  'i8jkzyeikwg': 48982,
#  'qr': 75219,
#  'tr9ch7zmdv6ax': 88316,
#  'r7kg6py0wvo4h': 75921,
#  '9fvy6f5s5fh6hqqg2kssbo4ea': 14162,
#  'aj95dj9ynejguyddngma': 18251,
#  'rgfy': 78132,
#  '2ipbsc3qd8f': 5267,
#  'ljbhdq9': 58732,
#  'cb4rhbvb1kfwjdpsny': 27005,
#  '86stfybvu3e3bxeax4f1kklhdpce3i': 12691,
#  'q7ktvttjhsynpkow2v0sd': 74508,
#  'ba9tvbdxpeq1o': 22056,
#  'lne1an7vpgahievi': 58927,
#  'wf6wvdeww8nbbmxy3focyblrl7bf': 95081,
#  'bp': 24680,
#  'f8a5twf': 40360,
#  'chr7l241gt691h2sfthubp': 28036,
#  'abgb6f8a015n9auvp6v1y7lqjfff6hfb5fbt9l': 16318,
#  'ta': 85976,
#  'fa7': 40407,
#  'uo': 90898,
#  '8uemy1gqmvd9fu8vyk5tbyqlgh9ygpf': 13438,
#  'vdx6r9yet9tunmbl2pe': 92142,
#  '2sesrap5flnrgkniz2xh': 5427,
#  'xtyma11drto4hn': 97533,
#  '8rd7a8rfgq6baid3ghba': 13386,
#  'ztz1nabo7knxg7s26fcakaahz6': 100801,
#  'of1kz6c': 67031,
#  'szxwkxxuzb278on9zz9rp': 85659,
#  'tfypz': 86949,
#  'ixe5gtrhmdba9rgsbcs4gaac': 53352,
#  '5yxs': 9956,
#  'mfa': 61699,
#  'q4xutswl9r': 74462,
#  'dq36old': 35307,
#  'ait': 18200,
#  'exz3rup9lyhpp1jyjzk4vpqqx7gn0sgbrw5vltgu': 40052,
#  '03udu': 546,
#  'nf0f': 65027,
#  'bkrcpv': 23823,
#  '5cletfqjp4uhlyhlsmsblickhgi9v': 9479,
#  '3wedzn9ay68hwngdt349z0e9hptyntp81vztd6g7': 7721,
#  '6bp0qv1ytzoxug4jtkfscp42fidqzc7kbvtrse2usxscwsaxv5w3m9': 10547,
#  '76ss9oxrw1': 11361,
#  'arm67': 20098,
#  'tjozmpzuzmqjyjh5ynhh9b': 87650,
#  's2ouji44smpxmccv6t': 79739,
#  'of4ch7kj4g7wswp6hu7': 67033,
#  'anukobbv': 19464,
#  'r7vsrqur67d9s63zrbrth7wusm7fulw2w2bfzrp0mz': 75929,
#  'oura7rer': 68325,
#  'xvq97frhn42he5tie': 97604,
#  '31dhibbxwy1st': 5700,
#  'nrc3yrpocrx0dvnxyc': 65939,
#  'wceyjdmdouelhgth': 94453,
#  '6xsaw4tlral6abzu9lbrh': 10983,
#  'geoe30q9lf8aopfvf9bq8jggwdcfpymh9ouqxmvg': 44260,
#  'x0pucd9ehtvp0fat3px1aycqbl72mlh': 96544,
#  'e6ge7tuw2t': 36966,
#  'qtweddcdxs3dzimnmkgmk4b66lfun6shqgobmo29pregmvvc5pdjtu': 75323,
#  'wvp': 96333,
#  'mt': 63387,
#  '60uj6l9rshnynz3txdavywufqgbaoh51gwbqbnn': 10044,
#  'w7pf': 93726,
#  'af10ns': 17472,
#  'm14ht68nkrudhyt9i': 59926,
#  '6d81wmv9tfoa': 10585,
#  'p9keaappoh9zv5zpsmza0nh5nmgdhhhwkcutjhzcvqvmtjdldzq0w2srkts': 68986,
#  'mbg0sw7ihbx7vywp0ttfdryabt7rlzyc5wf9bm': 61005,
#  '8g6qxnprr8932myzfyswnafvi7kj9hx': 13128,
#  '96wgf5s6pi1nqndtd6p0rxjv9ov0': 13830,
#  'wdsp91vv': 94737,
#  'siyjoftz8ohppu': 82227,
#  'kbzeljiwrbfbdry73jw': 55594,
#  'j00xwuwvurbydftf09oqpfbxfgryx7hpvdvc3bt': 53483,
#  'fqbuzuu6aktdipkli8wozir4rtdh0xu0': 42551,
#  'nz4': 66386,
#  'dsqfxp7p55stdu8qf': 36273,
#  's0': 79670,
#  'wkzcdshpvx2zrbackgjzshdcy7ls9tdft91vt3': 95674,
#  'pp': 72635,
#  'lx': 59773,
#  'e9n': 37061,
#  'o2znzdsnqgx7nol7hvje5zydzv0tm33bv5x6744dddwwzzk5tt1lncmah2pj92tuxq08': 66500,
#  'teqqa2gda3qcnfw5jn5zceacmf0b7nvlphmhloazphp9kvlmuw': 86740,
#  'qvlyvrkum': 75562,
#  'ytm5rzlnuaj': 99021,
#  'llaoo5mnlmpa0ndyj0ettc3bsgu1sseere6r03lcz1su': 58820,
#  'nl0gisu': 65399,
#  'i4s1zqrp3d': 48920,
#  'wx': 96423,
#  'qvmkk': 75564,
#  'rr1dceognr0r9ftdq6htiyxsseabek': 79062,
#  'cwct679iyoojeqjo523edgupjw76llwx1l': 31541,
#  '67nz': 10418,
#  ...}

# %%
X_train, X_test, y_train, y_test = train_test_split(all_features,data.CATEGORY, 
                                                   test_size=0.3, random_state=88)

# %%
X_train.shape
# Out:
# (4056, 102512)

# %%
X_test.shape
# Out:
# (1739, 102512)

# %%
classifier = MultinomialNB()

# %%
classifier.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
nr_correct=(y_test == classifier.predict(X_test)).sum()

# %%
print(f'{nr_correct} documents classified properly')
# Out:
# 1624 documents classified properly

# %%
nr_incorrect = y_test.size - nr_correct

# %%
print(f'Number of documents classified is {nr_incorrect}')
# Out:
# Number of documents classified is 115

# %%
fraction_wrong = nr_incorrect / (nr_correct + nr_incorrect)
print(f'The (testing) accuracy of the model is {1-fraction_wrong:.2%}')
# Out:
# The (testing) accuracy of the model is 93.39%

# %%
 classifier.score(X_test, y_test)
# Out:
# 0.933870040253019

# %% [markdown]
# For the testing dataset calculate the recall, precision and f1 score. Google for the scikit learn documentation on this topic to work it out.

# %%
recall_score (y_test, classifier.predict(X_test))
# Out:
# 0.809009009009009

# %%
precision_score (y_test, classifier.predict(X_test))
# Out:
# 0.980349344978166

# %%
f1_score(y_test, classifier.predict(X_test))
# Out:
# 0.8864758144126358

# %%
example = [
    'get viagra for free!',
    'need a mortgage? Reply to arrange a call with a specialist and get a quote',
    'Could you please help me with the project for tomorrow?',
    'Hello Jonathan, how about a game of golf tomorrow?',
    "Ski jumping is a winter sport in which competitors aim to achieve the longest jump after descending from a specially designed ramp on their skis. Along with jump length, competitor's style and other factors affect the final score. Ski jumping was first contested in Norway in the late 19th century, and later spread through Europe and North America in the early 20th century. Along with cross-country skiing, it constitutes the traditional group of Nordic skiing disciplines."
]

# %%
doc_term_matrix = vectorizer.transform(example)

# %%
classifier.predict(doc_term_matrix)
# Out:
# array([1, 1, 0, 0, 0])
